# %%
import os
import numpy as np
from keras.preprocessing import image
from keras.applications.vgg16 import VGG16, preprocess_input
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Load pre-trained model
model = VGG16(weights="imagenet", include_top=False)


# Function to extract features from an image
def extract_features(img_path):
    img = image.load_img(img_path, target_size=(224, 224))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features.flatten()


# Function to compare features of images
def compare_images(directory):
    features_dict = {}
    image_files = [
        f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))
    ]

    for image_file in image_files:
        features = extract_features(os.path.join(directory, image_file))
        if len(features_dict) == 0:
            features_dict[image_file] = features
        else:
            for existing_features in features_dict.items():
                similarity = cosine_similarity([features], [existing_features])
                if similarity > 0.95:  # similarity threshold
                    os.remove(os.path.join(directory, image_file))
                    print(f"Removed duplicate image: {image_file}")
                    break
            else:
                features_dict[image_file] = features


compare_images("../Kaggle Dataset/archive (5)/glass")
# Out:
# Removed duplicate image: glass_1491.jpg
# Removed duplicate image: glass_1817.jpg
# Removed duplicate image: glass_1846.jpg
# Removed duplicate image: glass_1865.jpg
# Removed duplicate image: glass_1874.jpg
# Removed duplicate image: glass_1917.jpg
# Removed duplicate image: glass_1918.jpg
# Removed duplicate image: glass_2117.jpg
# Removed duplicate image: glass_2128.jpg
# Removed duplicate image: glass_2155.jpg
# Removed duplicate image: glass_2207.jpg
# Removed duplicate image: glass_2280.jpg
# Removed duplicate image: glass_2327.jpg
# Removed duplicate image: glass_2406.jpg
# Removed duplicate image: glass_2431.jpg
# Removed duplicate image: glass_2483.jpg
# Removed duplicate image: glass_2485.jpg
# Removed duplicate image: glass_2529.jpg
# Removed duplicate image: glass_2566.jpg
# Removed duplicate image: glass_2572.jpg
# Removed duplicate image: glass_2651.jpg
# Removed duplicate image: glass_2672.jpg
# Removed duplicate image: glass_2675.jpg
# Removed duplicate image: glass_2724.jpg
# Removed duplicate image: glass_2729.jpg
# Removed duplicate image: glass_2773.jpg
# Removed duplicate image: glass_2839.jpg
# Removed duplicate image: glass_2849.jpg
# Removed duplicate image: glass_2860.jpg
# Removed duplicate image: glass_2881.jpg
# Removed duplicate image: glass_2892.jpg
# Removed duplicate image: glass_2894.jpg
# Removed duplicate image: glass_2960.jpg
# Removed duplicate image: glass_2980.jpg
# Removed duplicate image: glass_2990.jpg
# Removed duplicate image: glass_3009.jpg
# Removed duplicate image: glass_3038.jpg
# Removed duplicate image: glass_3043.jpg
# Removed duplicate image: glass_3112.jpg
# Removed duplicate image: glass_3173.jpg
# Removed duplicate image: glass_3201.jpg
# Removed duplicate image: glass_3217.jpg
# Removed duplicate image: glass_3220.jpg
# Removed duplicate image: glass_3226.jpg
# Removed duplicate image: glass_3269.jpg
# Removed duplicate image: glass_3286.jpg
# Removed duplicate image: glass_3315.jpg
# Removed duplicate image: glass_3355.jpg
# Removed duplicate image: glass_3357.jpg
# Removed duplicate image: glass_3358.jpg
# Removed duplicate image: glass_3401.jpg
# Removed duplicate image: glass_3462.jpg
# Removed duplicate image: glass_3516.jpg
# Removed duplicate image: glass_3546.jpg
# Removed duplicate image: glass_3552.jpg
# Removed duplicate image: glass_3575.jpg
# Removed duplicate image: glass_3581.jpg
# Removed duplicate image: glass_3593.jpg
# Removed duplicate image: glass_3620.jpg
# Removed duplicate image: glass_3632.jpg
# Removed duplicate image: glass_3635.jpg
# Removed duplicate image: glass_3673.jpg
# Removed duplicate image: glass_3679.jpg
# Removed duplicate image: glass_3712.jpg
# Removed duplicate image: glass_3714.jpg
# Removed duplicate image: glass_3741.jpg
# Removed duplicate image: glass_3757.jpg
# Removed duplicate image: glass_3773.jpg
# Removed duplicate image: glass_3806.jpg
# Removed duplicate image: glass_3834.jpg
# Removed duplicate image: glass_3839.jpg
# Removed duplicate image: glass_3863.jpg
# Removed duplicate image: glass_3869.jpg
# Removed duplicate image: glass_3912.jpg
# Removed duplicate image: glass_3921.jpg
# Removed duplicate image: glass_3973.jpg
# Removed duplicate image: glass_3998.jpg
# Removed duplicate image: glass_4030.jpg
# Removed duplicate image: glass_4032.jpg
# Removed duplicate image: glass_4033.jpg
# Removed duplicate image: glass_4046.jpg
# Removed duplicate image: glass_4051.jpg
# Removed duplicate image: glass_4055.jpg
# Removed duplicate image: glass_4074.jpg
# Removed duplicate image: glass_4104.jpg
# Removed duplicate image: glass_4107.jpg
# Removed duplicate image: glass_4125.jpg
# Removed duplicate image: glass_4141.jpg
# Removed duplicate image: glass_4179.jpg
# Removed duplicate image: glass_4198.jpg
# Removed duplicate image: glass_4216.jpg
# Removed duplicate image: glass_4242.jpg
# Removed duplicate image: glass_4268.jpg
# Removed duplicate image: glass_4285.jpg
# Removed duplicate image: glass_4291.jpg
# Removed duplicate image: glass_4300.jpg
# Removed duplicate image: glass_4311.jpg
# Removed duplicate image: glass_4333.jpg
# Removed duplicate image: glass_4336.jpg
# Removed duplicate image: glass_4347.jpg
# Removed duplicate image: glass_4363.jpg
# Removed duplicate image: glass_4398.jpg
# Removed duplicate image: glass_4408.jpg
# Removed duplicate image: glass_4432.jpg
# Removed duplicate image: glass_4438.jpg
# Removed duplicate image: glass_4455.jpg
# Removed duplicate image: glass_4457.jpg
# Removed duplicate image: glass_4469.jpg
# Removed duplicate image: glass_4493.jpg
# Removed duplicate image: glass_4506.jpg
# Removed duplicate image: glass_4523.jpg
# Removed duplicate image: glass_4533.jpg
# Removed duplicate image: glass_4558.jpg
# Removed duplicate image: glass_4565.jpg
# Removed duplicate image: glass_4576.jpg
# Removed duplicate image: glass_4581.jpg
# Removed duplicate image: glass_4602.jpg
# Removed duplicate image: glass_4615.jpg
# Removed duplicate image: glass_4632.jpg
# Removed duplicate image: glass_4647.jpg
# Removed duplicate image: glass_4671.jpg
# Removed duplicate image: glass_500.jpg
# Removed duplicate image: glass_505.jpg
# Removed duplicate image: glass_527.jpg
# Removed duplicate image: glass_532.jpg
# Removed duplicate image: glass_535.jpg
# Removed duplicate image: glass_543.jpg
# Removed duplicate image: glass_546.jpg
# Removed duplicate image: glass_554.jpg
# Removed duplicate image: glass_566.jpg
# Removed duplicate image: glass_598.jpg
# Removed duplicate image: glass_620.jpg
# Removed duplicate image: glass_626.jpg
# Removed duplicate image: glass_633.jpg
# Removed duplicate image: glass_652.jpg
# Removed duplicate image: glass_661.jpg
# Removed duplicate image: glass_701.jpg
# Removed duplicate image: glass_743.jpg
# Removed duplicate image: glass_752.jpg
# Removed duplicate image: glass_758.jpg
# Removed duplicate image: glass_759.jpg
# Removed duplicate image: glass_786.jpg
# Removed duplicate image: glass_795.jpg
# Removed duplicate image: glass_803.jpg
# Removed duplicate image: glass_819.jpg
# Removed duplicate image: glass_837.jpg
# Removed duplicate image: glass_857.jpg
# Removed duplicate image: glass_862.jpg
# Removed duplicate image: glass_864.jpg
# Removed duplicate image: glass_884.jpg
# Removed duplicate image: glass_907.jpg
# Removed duplicate image: glass_915.jpg
# Removed duplicate image: glass_916.jpg
# Removed duplicate image: glass_934.jpg
# Removed duplicate image: glass_939.jpg
# Removed duplicate image: glass_953.jpg
# Removed duplicate image: glass_971.jpg
# Removed duplicate image: glass_983.jpg
# Removed duplicate image: glass_985.jpg
# Removed duplicate image: glass_994.jpg
